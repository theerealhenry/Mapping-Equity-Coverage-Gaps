# %% [markdown]
# # 04 — Bias Discovery
#
# **Owned by**: Stage 8 (Diagnostic modeling & hypothesis funnel) and Stage 9 (Statistical confirmation & Bias Discovery writeup)
#
# Named explicitly as a Stage 8 deliverable ("contributions to `notebooks/04_bias_discovery.ipynb`") and continues through Stage 9's confirmatory analysis — the two-mode clustering, explanatory modeling and SHAP evidence from Stage 8, and the bootstrap/permutation/FDR-corrected confirmatory statistics and Bias API replica cross-checks from Stage 9, feeding the flagship Bias Discovery findings documented in `docs/bias_discovery.md`.
#
# Intentionally empty — populated starting Stage 8.
